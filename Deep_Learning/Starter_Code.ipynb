# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10  \
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS
# 0       Independent          C1000    ProductDev   Association       1  \
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns = ['EIN','NAME'], inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE
# 0                  T10       Independent          C1000    ProductDev  \
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT
# 0       Association       1              0                      N      5000  \
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
for i in application_df.columns:
    print(i, len(application_df[i].unique()))
# Out:
# APPLICATION_TYPE 17
# AFFILIATION 6
# CLASSIFICATION 71
# USE_CASE 5
# ORGANIZATION 4
# STATUS 2
# INCOME_AMT 9
# SPECIAL_CONSIDERATIONS 2
# ASK_AMT 8747
# IS_SUCCESSFUL 2

# %%
# Look at APPLICATION_TYPE value counts for binning
app_counts = application_df['APPLICATION_TYPE'].value_counts()
app_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_counts[app_counts<200].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x >1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts<300].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df)
application_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other
# 0       1     5000              1                   False  \
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3
# 0                  True                 False                False  \
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...
# 0                False                False                False  ...  \
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999
# 0              False                   False                     False  \
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999
# 0               False             False                   False  \
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N
# 0            False              False                      True  \
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dummies.drop('IS_SUCCESSFUL', axis=1).values
y = application_dummies['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])

hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu', input_dim=number_input_features))


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 405
#
#  dense_1 (Dense)             (None, 18)                180
#
#  dense_2 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 604
# Trainable params: 604
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 645us/step - loss: 0.5932 - accuracy: 0.7030
# Epoch 2/50
# 804/804 [==============================] - 0s 618us/step - loss: 0.5629 - accuracy: 0.7293
# Epoch 3/50
# 804/804 [==============================] - 1s 628us/step - loss: 0.5566 - accuracy: 0.7304
# Epoch 4/50
# 804/804 [==============================] - 0s 617us/step - loss: 0.5537 - accuracy: 0.7301
# Epoch 5/50
# 804/804 [==============================] - 0s 613us/step - loss: 0.5522 - accuracy: 0.7310
# Epoch 6/50
# 804/804 [==============================] - 1s 625us/step - loss: 0.5515 - accuracy: 0.7297
# Epoch 7/50
# 804/804 [==============================] - 1s 625us/step - loss: 0.5503 - accuracy: 0.7321
# Epoch 8/50
# 804/804 [==============================] - 1s 627us/step - loss: 0.5493 - accuracy: 0.7320
# Epoch 9/50
# 804/804 [==============================] - 1s 634us/step - loss: 0.5494 - accuracy: 0.7325
# Epoch 10/50
# 804/804 [==============================] - 0s 617us/step - loss: 0.5487 - accuracy: 0.7327
# Epoch 11/50
# 804/804 [==============================] - 0s 619us/step - loss: 0.5480 - accuracy: 0.7333
# Epoch 12/50
# 804/804 [==============================] - 0s 610us/step - loss: 0.5477 - accuracy: 0.7335
# Epoch 13/50
# 804/804 [==============================] - 0s 613us/step - loss: 0.5475 - accuracy: 0.7339
# Epoch 14/50
# 804/804 [==============================] - 0s 605us/step - loss: 0.5473 - accuracy: 0.7341
# Epoch 15/50
# 804/804 [==============================] - 0s 619us/step - loss: 0.5469 - accuracy: 0.7337
# Epoch 16/50
# 804/804 [==============================] - 1s 670us/step - loss: 0.5466 - accuracy: 0.7344
# Epoch 17/50
# 804/804 [==============================] - 1s 668us/step - loss: 0.5464 - accuracy: 0.7338
# Epoch 18/50
# 804/804 [==============================] - 1s 659us/step - loss: 0.5461 - accuracy: 0.7341
# Epoch 19/50
# 804/804 [==============================] - 1s 640us/step - loss: 0.5461 - accuracy: 0.7343
# Epoch 20/50
# 804/804 [==============================] - 1s 637us/step - loss: 0.5459 - accuracy: 0.7346
# Epoch 21/50
# 804/804 [==============================] - 1s 643us/step - loss: 0.5460 - accuracy: 0.7349
# Epoch 22/50
# 804/804 [==============================] - 1s 650us/step - loss: 0.5458 - accuracy: 0.7347
# Epoch 23/50
# 804/804 [==============================] - 1s 625us/step - loss: 0.5456 - accuracy: 0.7342
# Epoch 24/50
# 804/804 [==============================] - 1s 637us/step - loss: 0.5453 - accuracy: 0.7350
# Epoch 25/50
# 804/804 [==============================] - 1s 632us/step - loss: 0.5455 - accuracy: 0.7345
# Epoch 26/50
# 804/804 [==============================] - 1s 634us/step - loss: 0.5452 - accuracy: 0.7351
# Epoch 27/50
# 804/804 [==============================] - 1s 643us/step - loss: 0.5446 - accuracy: 0.7348
# Epoch 28/50
# 804/804 [==============================] - 1s 630us/step - loss: 0.5449 - accuracy: 0.7344
# Epoch 29/50
# 804/804 [==============================] - 1s 628us/step - loss: 0.5444 - accuracy: 0.7345
# Epoch 30/50
# 804/804 [==============================] - 1s 630us/step - loss: 0.5441 - accuracy: 0.7368
# Epoch 31/50
# 804/804 [==============================] - 0s 618us/step - loss: 0.5448 - accuracy: 0.7356
# Epoch 32/50
# 804/804 [==============================] - 0s 618us/step - loss: 0.5444 - accuracy: 0.7357
# Epoch 33/50
# 804/804 [==============================] - 0s 613us/step - loss: 0.5437 - accuracy: 0.7362
# Epoch 34/50
# 804/804 [==============================] - 1s 641us/step - loss: 0.5441 - accuracy: 0.7358
# Epoch 35/50
# 804/804 [==============================] - 0s 617us/step - loss: 0.5437 - accuracy: 0.7355
# Epoch 36/50
# 804/804 [==============================] - 1s 625us/step - loss: 0.5438 - accuracy: 0.7352
# Epoch 37/50
# 804/804 [==============================] - 1s 623us/step - loss: 0.5432 - accuracy: 0.7352
# Epoch 38/50
# 804/804 [==============================] - 0s 618us/step - loss: 0.5440 - accuracy: 0.7357
# Epoch 39/50
# 804/804 [==============================] - 1s 622us/step - loss: 0.5434 - accuracy: 0.7361
# Epoch 40/50
# 804/804 [==============================] - 1s 624us/step - loss: 0.5432 - accuracy: 0.7347
# Epoch 41/50
# 804/804 [==============================] - 1s 632us/step - loss: 0.5435 - accuracy: 0.7369
# Epoch 42/50
# 804/804 [==============================] - 0s 612us/step - loss: 0.5434 - accuracy: 0.7366
# Epoch 43/50
# 804/804 [==============================] - 0s 620us/step - loss: 0.5431 - accuracy: 0.7357
# Epoch 44/50
# 804/804 [==============================] - 1s 622us/step - loss: 0.5431 - accuracy: 0.7358
# Epoch 45/50
# 804/804 [==============================] - 0s 608us/step - loss: 0.5431 - accuracy: 0.7365
# Epoch 46/50
# 804/804 [==============================] - 1s 638us/step - loss: 0.5431 - accuracy: 0.7371
# Epoch 47/50
# 804/804 [==============================] - 1s 627us/step - loss: 0.5431 - accuracy: 0.7362
# Epoch 48/50
# 804/804 [==============================] - 1s 622us/step - loss: 0.5428 - accuracy: 0.7358
# Epoch 49/50
# 804/804 [==============================] - 0s 609us/step - loss: 0.5425 - accuracy: 0.7359
# Epoch 50/50
# 804/804 [==============================] - 0s 604us/step - loss: 0.5429 - accuracy: 0.7365

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5541 - accuracy: 0.7251 - 217ms/epoch - 810us/step
# Loss: 0.5540740489959717, Accuracy: 0.7251312136650085

# %%
# Export our model to HDF5 file
nn.save('../h5_files/AlphabetSoupCharity_model_1.h5')

# %%
# Plot the Accuracy
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))
history_df.plot(y = 'accuracy')
# Out:
# <Axes: >
